# %% [markdown]
# # Multi-Head Attention
#
# Implement MHA as the baseline decoder attention layer: projections, head split/merge, causal prefill, decode with explicit KV cache, and prefill/decode equivalence.

# %% [markdown]
# ## Scope

# %% [markdown]
# - **Shape Contract:** MHA uses the same number of query heads and KV heads.
# - **Implementation Target:** Build a small `MultiHeadAttention` module and verify decode matches causal prefill.
# - **Package Target:** Move the cleaned implementation into `attention_forge/attention/mha.py`.

# %% [markdown]
# ## Starter Cell

# %%
import torch

torch.manual_seed(0)

B, T, H, D = 2, 16, 4, 8
C = H * D

shapes = {
    "x": [B, T, C],
    "q": [B, H, T, D],
    "k": [B, H, T, D],
    "v": [B, H, T, D],
    "kv_cache": [B, H, T, D],
}
shapes

# %% [markdown]
# ## Next Work
#
# This notebook will be expanded into a full from-scratch derivation, then the cleaned implementation will move into package code.
