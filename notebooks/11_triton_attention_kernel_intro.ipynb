# %% [markdown]
# # Triton Attention Kernel Intro
#
# Explain the kernel path for decode attention after the PyTorch reference is correct.

# %% [markdown]
# ## Scope

# %% [markdown]
# - **Kernel Contract:** Inputs, block sizes, memory layout, and output shape should be explicit before writing Triton.
# - **Implementation Target:** Start with a tiny decode attention kernel, then compare against PyTorch.
# - **Package Target:** Move reusable kernels into `attention_forge/kernels/`.

# %% [markdown]
# ## Starter Cell

# %%
kernel_plan = {
    "first_kernel": "single-token decode attention",
    "baseline": "torch scaled_dot_product_attention or manual attention",
    "metrics": ["correctness", "latency", "memory reads"],
}
kernel_plan

# %% [markdown]
# ## Next Work
#
# This notebook will be expanded into a full from-scratch derivation, then the cleaned implementation will move into package code.
