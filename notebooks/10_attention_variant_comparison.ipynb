# %% [markdown]
# # Attention Variant Comparison
#
# Compare attention variants by cache shape, cached scalars, read pattern, implementation complexity, and likely quality risk.

# %% [markdown]
# ## Scope

# %% [markdown]
# - **Comparison Axes:** Compute/storage/read-pattern/quality-risk should be separated instead of collapsed into one score.
# - **Implementation Target:** Build tables and plots comparing MHA, MQA, GQA, MLA, DSA, CSA, and MiniMax variants.
# - **Package Target:** Move reusable comparison helpers into `attention_forge/bench/`.

# %% [markdown]
# ## Starter Cell

# %%
variants = [
    ["MHA", "full KV per query head", "dense"],
    ["MQA", "one shared KV head", "dense"],
    ["GQA", "grouped KV heads", "dense"],
    ["MLA", "latent cache", "dense or sparse"],
    ["DSA/CSA", "full or compressed KV", "selected reads"],
]
variants

# %% [markdown]
# ## Next Work
#
# This notebook will be expanded into a full from-scratch derivation, then the cleaned implementation will move into package code.
